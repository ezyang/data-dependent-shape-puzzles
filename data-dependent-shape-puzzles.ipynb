# %% [markdown]
# When working on compiling or exporting code that has data dependent sizes, it's common to run into GuardOnDataDependentSymNode errors. Unfortunately, if it's the first time you've needed to fix one of these problems, it can be quite difficult to get your bearing in a real world model. The purpose of these puzzlers is to give you some practice fixing GuardOnDataDependentSymNode errors in a controlled setting, so you can get some sense for what works and doesn't and build your mental model.
#
# I highly recommend reading [Dealing with GuardOnDataDependentSymNode errors](https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit#heading=h.44gwi83jepaj) document first.  If you have questions or need help, you can reach out to [PT2 Data Dependent Shapes WG](https://fb.workplace.com/groups/6829516587176185).

# %%
import torch
import torch._dynamo.config
from typing import List, Union, Any
from torch import Tensor
from torch.fx.experimental.symbolic_shapes import guard_size_oblivious
from dataclasses import dataclass
import random
# Out:
# I0507 135202.330 _utils_internal.py:275] NCCL_DEBUG env var is set to None
# I0507 135202.331 _utils_internal.py:284] NCCL_DEBUG is WARN from /etc/nccl.conf

# %%
torch._dynamo.config.capture_scalar_outputs = True
torch._dynamo.config.capture_dynamic_output_shape_ops = True

TEMPLATE = True
MSG = "🎉 Correct! 🎉"

@dataclass
class U:
    # Describes an unbacked SymInt whose real value is val, for testing
    val: int

UnpackedTy = Union[int, U]
PackedTy = Union[int, Tensor]

def assert_eq(actual, expected):
    if isinstance(actual, Tensor) or isinstance(expected, Tensor):
        assert isinstance(actual, Tensor), actual
        assert isinstance(expected, Tensor), expected
        cond = torch.allclose(actual, expected)
    elif isinstance(actual, list) or isinstance(expected, list):
        assert isinstance(actual, list), actual
        assert isinstance(expected, list), expected
        for a, e in zip(actual, expected):
            assert_eq(a, e)
        cond = len(actual) == len(expected)
    else:
        assert type(actual) == type(expected), (actual, expected)
        cond = actual == expected
        assert isinstance(cond, bool), (actual, expected)
    if not cond:
        raise RuntimeError(f"{actual} != {expected}")

def pack_size(s: UnpackedTy) -> PackedTy:
    if isinstance(s, U):
        return torch.tensor(s.val)
    else:
        return s

def pack_sizes(shape: UnpackedTy) -> List[PackedTy]:
    return [pack_size(s) for s in shape]

# NB: the unpack functions will be Dynamo traced, so they're not really inverses
def unpack_size(s: PackedTy) -> int:
    if isinstance(s, Tensor):
        r = s.item()
        torch._check_is_size(r)
        return r
    else:
        return s

def unpack_sizes(ss: List[PackedTy]) -> List[int]:
    return [unpack_size(s) for s in ss]

def unpack_tensor(ss: List[PackedTy]) -> Tensor:
    return torch.randn(unpack_sizes(ss))

def force_guard(x: bool):
    if x:
        return torch.tensor(True)
    else:
        return torch.tensor(False)

def run_test(fn):
    torch._dynamo.reset()
    fn()
    print(MSG)

# %% [markdown]
# ## Basic symbolic reasoning
#
# Here are some basic warmups to test your understanding of [Dealing with GuardOnDataDependentSymNode errors](https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit#heading=h.44gwi83jepaj), and familiarize you with how this notebook is setup.
#
# **[check]** Use torch._check to resolve the compile time error below.

# %%
@torch.compile(backend="eager", fullgraph=True)
def cf_check(x):
    u0, u1 = x.tolist()
    torch._check(u0 * 2 == u1 * 3)
    # Do not modify the code below here (imagine it's in framework code you can't edit)
    # NB: In future exercises, we'll use force_guard as a shorthand for this pattern.
    if u0 * 2 == u1 * 3:
        return torch.tensor(True)
    else:
        return torch.tensor(False)

@run_test
def test_check():
    assert cf_check(torch.tensor([12, 8])).item()
# Out:
# 🎉 Correct! 🎉

# %% [markdown]
# **[checkand]**  It is best not to use logical conjunction inside `torch._check` operators.  Modify the torch._check below so that compilation passes.

# %%
@torch.compile(backend="eager", fullgraph=True)
def cf_checkand(x):
    u0, u1 = x.tolist()
    torch._check((u0 // 3 == 0) and (u1 // 5 == 0))
    # Do not modify the code below
    return force_guard((u0 // 3 == 0) and (u1 // 5 == 0))

@run_test
def test_checkand():
    assert cf_checkand(torch.tensor([2, 4]))
# Out:
# E0507 13:52:28.472321 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq((u0//3), 0), None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1001, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1000 try:
# -> 1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:748, in guard_scalar(a)
#     747 if isinstance(a, (SymBool, bool)):
# --> 748     return guard_bool(a)
#     749 elif isinstance(a, (SymInt, int)):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:921, in guard_bool(a)
#     920 if isinstance(a, SymBool):
# --> 921     return a.node.guard_bool("", 0)  # NB: uses Python backtrace
#     922 assert type(a) is bool, a
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Eq((u0//3), 0) (unhinted: Eq((u0//3), 0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1393649969.py", line 4, in cf_checkand
#     torch._check((u0 // 3 == 0) and (u1 // 5 == 0))
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5     # Do not modify the code below
#       6     return force_guard((u0 // 3 == 0) and (u1 // 5 == 0))
#       8 @run_test
# ----> 9 def test_checkand():
#      10     assert cf_checkand(torch.tensor([2, 4]))
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[4], line 10, in test_checkand()
#       8 @run_test
#       9 def test_checkand():
# ---> 10     assert cf_checkand(torch.tensor([2, 4]))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:448, in generic_jump.<locals>.inner(self, inst)
#     446 elif isinstance(value, SymNodeVariable):
#     447     try:
# --> 448         eval_result = value.evaluate_expr(self.output)
#     449     except exc.UserError as e:
#     450         if self.should_compile_partial_graph():
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1003, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
# -> 1003     raise UserError(  # noqa: TRY200
#    1004         UserErrorType.ANTI_PATTERN,
#    1005         f"Consider annotating your code using torch._check*(). {str(e)}",
#    1006         case_name="constrain_as_size_example",
#    1007     )
#
# UserError: Consider annotating your code using torch._check*(). Could not guard on data-dependent expression Eq((u0//3), 0) (unhinted: Eq((u0//3), 0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1393649969.py", line 4, in cf_checkand
#     torch._check((u0 // 3 == 0) and (u1 // 5 == 0))
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/1393649969.py", line 4, in cf_checkand
#     torch._check((u0 // 3 == 0) and (u1 // 5 == 0))
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[checksize]** Marking a variable as size-like means we will assume it is `>= 2` inside size oblivious guards, but we will still permit it to have 0/1 value at runtime.

# %%
@torch.compile(backend="eager", fullgraph=True)
def cf_checksize(x):
    u0 = x.item()
    # For extra credit, mark u0 as size-like WITHOUT explicitly calling torch._check_is_size
    pass
    return force_guard(guard_size_oblivious(u0 != 0))

@run_test
def test_checksize():
    assert cf_checksize(torch.tensor(5)).item()
    assert cf_checksize(torch.tensor(0)).item()  # this is true!  You can make some strange things happen if you combine this with torch._check(u0 == 0)
# Out:
# 🎉 Correct! 🎉

# %% [markdown]
# **[implicitsize]** Some APIs do not implicitly specify a size is size-like.  So you may need to explicitly specify it in those situations.  When this is not a bug in PyTorch, this is typically because the API accepts sentinel values like -1 and you have to explicitly indicate that this is not a permitted input.

# %%
@torch.compile(backend="eager", fullgraph=True)
def cf_implicitsize(x, y):
    u0 = x.item()
    pass
    torch._check(u0 < y.size(0))
    return y[u0]

@run_test
def test_implicitsize():
    assert cf_implicitsize(torch.tensor(2), torch.randn(10)).item()
# Out:
# E0507 13:52:37.226803 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(-u0 > 10, None), **{'fx_node': None})
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] failed while attempting to run meta for aten.select.int
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] Traceback (most recent call last):
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py", line 1624, in _dispatch_impl
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     r = func(*args, **kwargs)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_ops.py", line 630, in __call__
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     return self_._op(*args, **kwargs)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py", line 5069, in meta_select
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     not (-index > size or index >= size),
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py", line 378, in __bool__
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     return self.node.bool_()
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py", line 439, in bool_
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     return self.guard_bool("", 0)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py", line 377, in guard_bool
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py", line 244, in wrapper
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     return fn(*args, **kwargs)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py", line 4746, in evaluate_expr
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     raise self._make_data_dependent_error(
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode: Could not guard on data-dependent expression -u0 > 10 (unhinted: -u0 > 10).  (Size-like symbols: none)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] Potential framework code culprit (scroll up for full backtrace):
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py", line 5069, in meta_select
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     not (-index > size or index >= size),
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] For more information, run with TORCH_LOGS="dynamic"
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] User Stack (most recent call last):
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   (snipped, see stack below for prefix)
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]   File "/tmp/ipykernel_2254597/1873525780.py", line 6, in cf_implicitsize
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]     return y[u0]
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0]
# E0507 13:52:37.252297 140547765035008 torch/_subclasses/fake_tensor.py:1628] [0/0] For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1624, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1623     with in_kernel_invocation_manager(self):
# -> 1624         r = func(*args, **kwargs)
#    1625 except NotImplementedError as not_implemented_error:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_ops.py:630, in OpOverload.__call__(self_, *args, **kwargs)
#     627 def __call__(self_, *args, **kwargs):  # noqa: B902
#     628     # use `self_` to avoid naming collide with aten ops arguments that
#     629     # are named "self". This way, all the aten ops can be called by kwargs.
# --> 630     return self_._op(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py:5069, in meta_select(self, dim, index)
#    5066 size = self.size(dim)
#    5068 torch._check_index(
# -> 5069     not (-index > size or index >= size),
#    5070     lambda: f"select(): index {index} out of range for tensor of size "
#    5071     f"{self.size()} at dimension {dim}",
#    5072 )
#    5074 index = index if index >= 0 else index + size
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py:378, in SymBool.__bool__(self)
#     377 def __bool__(self):
# --> 378     return self.node.bool_()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:439, in SymNode.bool_(self)
#     438 def bool_(self):
# --> 439     return self.guard_bool("", 0)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression -u0 > 10 (unhinted: -u0 > 10).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py", line 5069, in meta_select
#     not (-index > size or index >= size),
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1873525780.py", line 6, in cf_implicitsize
#     return y[u0]
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1762, in get_fake_value(node, tx, allow_non_graph_fake)
#    1761     with tx.fake_mode, enable_python_dispatcher():
# -> 1762         ret_val = wrap_fake_exception(
#    1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1277, in wrap_fake_exception(fn)
#    1276 try:
# -> 1277     return fn()
#    1278 except UnsupportedFakeTensorException as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1763, in get_fake_value.<locals>.<lambda>()
#    1761     with tx.fake_mode, enable_python_dispatcher():
#    1762         ret_val = wrap_fake_exception(
# -> 1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1898, in run_node(tracer, node, args, kwargs, nnmodule)
#    1897     except Exception as e:
# -> 1898         raise RuntimeError(make_error_message(e)).with_traceback(
#    1899             e.__traceback__
#    1900         ) from e
#    1902 raise AssertionError(op)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1624, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1623     with in_kernel_invocation_manager(self):
# -> 1624         r = func(*args, **kwargs)
#    1625 except NotImplementedError as not_implemented_error:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_ops.py:630, in OpOverload.__call__(self_, *args, **kwargs)
#     627 def __call__(self_, *args, **kwargs):  # noqa: B902
#     628     # use `self_` to avoid naming collide with aten ops arguments that
#     629     # are named "self". This way, all the aten ops can be called by kwargs.
# --> 630     return self_._op(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py:5069, in meta_select(self, dim, index)
#    5066 size = self.size(dim)
#    5068 torch._check_index(
# -> 5069     not (-index > size or index >= size),
#    5070     lambda: f"select(): index {index} out of range for tensor of size "
#    5071     f"{self.size()} at dimension {dim}",
#    5072 )
#    5074 index = index if index >= 0 else index + size
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py:378, in SymBool.__bool__(self)
#     377 def __bool__(self):
# --> 378     return self.node.bool_()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:439, in SymNode.bool_(self)
#     438 def bool_(self):
# --> 439     return self.guard_bool("", 0)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# RuntimeError: Failed running call_function <built-in method select of type object at 0x556d77e78f88>(*(FakeTensor(..., size=(10,)), 0, u0), **{}):
# Could not guard on data-dependent expression -u0 > 10 (unhinted: -u0 > 10).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py", line 5069, in meta_select
#     not (-index > size or index >= size),
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1873525780.py", line 6, in cf_implicitsize
#     return y[u0]
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5     torch._check(u0 < y.size(0))
#       6     return y[u0]
#       8 @run_test
# ----> 9 def test_implicitsize():
#      10     assert cf_implicitsize(torch.tensor(2), torch.randn(10)).item()
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[6], line 10, in test_implicitsize()
#       8 @run_test
#       9 def test_implicitsize():
# ---> 10     assert cf_implicitsize(torch.tensor(2), torch.randn(10)).item()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:231, in stack_op.<locals>.impl(self, inst)
#     229 @functools.wraps(fn)
#     230 def impl(self: "InstructionTranslatorBase", inst: Instruction):
# --> 231     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:925, in BuiltinVariable._handle_insert_op_in_graph(self, tx, args, kwargs)
#     921         if fn is operator.truediv and isinstance(
#     922             args[0], variables.UnspecializedPythonVariable
#     923         ):
#     924             args[0] = args[0].convert_to_constant(tx)
# --> 925         return wrap_fx_proxy(tx, proxy)
#     927 except NotImplementedError:
#     928     unimplemented(f"partial tensor op: {self} {args} {kwargs}")
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1519, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1511 kwargs = {
#    1512     "tx": tx,
#    1513     "proxy": proxy,
#    (...)
#    1516     **options,
#    1517 }
#    1518 if subclass_type is None:
# -> 1519     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1520 else:
#    1521     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1604, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1600 # with preserve_rng_state():
#    1601 if example_value is None:
#    1602     # only allow_non_graph_fake in this instance because we handle the non-fake
#    1603     # cases properly below.
# -> 1604     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1606 # Handle recursive calls here
#    1607 elif maybe_get_fake_mode(example_value) is tx.fake_mode:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1817, in get_fake_value(node, tx, allow_non_graph_fake)
#    1809     unimplemented(
#    1810         f"unsupported operator: {cause.func} ({import_suggestion}see "
#    1811         "https://docs.google.com/document/d/1GgvOe7C8_NVOMLOCwDaYV1mXXyHMXY7ExoewHqooxrs/edit#heading=h.64r4npvq0w0"
#    1812         " for how to fix)"
#    1813     )
#    1814 elif isinstance(
#    1815     cause, torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode
#    1816 ):
# -> 1817     raise UserError(  # noqa: TRY200
#    1818         UserErrorType.CONSTRAINT_VIOLATION,
#    1819         "Tried to use data-dependent value in the subsequent computation. "
#    1820         "This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  "
#    1821         "You will need to explicitly give hint to the compiler. Please take a look at "
#    1822         f"torch._check OR torch._check_is_size APIs.  {cause}",
#    1823         case_name="constrain_as_size_example",
#    1824     )
#    1825 elif isinstance(cause, ValueRangeError):
#    1826     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
#
# UserError: Tried to use data-dependent value in the subsequent computation. This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  You will need to explicitly give hint to the compiler. Please take a look at torch._check OR torch._check_is_size APIs.  Could not guard on data-dependent expression -u0 > 10 (unhinted: -u0 > 10).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_meta_registrations.py", line 5069, in meta_select
#     not (-index > size or index >= size),
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1873525780.py", line 6, in cf_implicitsize
#     return y[u0]
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/1873525780.py", line 6, in cf_implicitsize
#     return y[u0]
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[nomemo]** Some APIs in PyTorch accept Tensor directly where int is expected. This results in an implicit item() call. Although sometimes we memoize the returned unbacked SymInts, in general it is better to make sure you call item() once, and use the resulting unbacked SymInt consistently through the rest of the program.  Fix the program below.  Note that the commented `torch._check_is_size` does not work (why?)

# %%
@torch.compile(fullgraph=True, backend="eager")
def cf_nomemo(x, y):
    # torch._check_is_size(y[0])
    return x.unsqueeze(1).expand(-1, y[0])

@run_test
def test_nomemo():
    cf_nomemo(torch.randn(8), torch.tensor([2]))
# Out:
# E0507 13:52:44.432424 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq(u0, 1), None), **{'fx_node': None, 'size_oblivious': True})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1882, in run_node(tracer, node, args, kwargs, nnmodule)
#    1881 elif op == "call_method":
# -> 1882     return getattr(args[0], node.target)(*args[1:], **kwargs)
#    1883 elif op == "call_module":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1557, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1556     with self:
# -> 1557         return decomposition_table[func](*args, **kwargs)
#    1559 with self:
#    1560     # Decomposes CompositeImplicitAutograd ops
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_refs/__init__.py:2933, in expand(a, *shape)
#    2931 requested_length = shape[offset_idx]
#    2932 torch._check(
# -> 2933     guard_size_oblivious(requested_length == x)
#    2934     or guard_size_oblivious(x == 1)
#    2935     or requested_length == -1,
#    2936     lambda: f"expand: attempting to expand a dimension of length {x}!",
#    2937 )
#    2939 shape_[offset_idx] = requested_length if requested_length != -1 else x
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Eq(u0, 1) (unhinted: Eq(u0, 1)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_refs/__init__.py", line 2933, in expand
#     guard_size_oblivious(requested_length == x)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1195362613.py", line 5, in cf_nomemo
#     return x.unsqueeze(1).expand(-1, y[0])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1762, in get_fake_value(node, tx, allow_non_graph_fake)
#    1761     with tx.fake_mode, enable_python_dispatcher():
# -> 1762         ret_val = wrap_fake_exception(
#    1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1277, in wrap_fake_exception(fn)
#    1276 try:
# -> 1277     return fn()
#    1278 except UnsupportedFakeTensorException as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1763, in get_fake_value.<locals>.<lambda>()
#    1761     with tx.fake_mode, enable_python_dispatcher():
#    1762         ret_val = wrap_fake_exception(
# -> 1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1898, in run_node(tracer, node, args, kwargs, nnmodule)
#    1897     except Exception as e:
# -> 1898         raise RuntimeError(make_error_message(e)).with_traceback(
#    1899             e.__traceback__
#    1900         ) from e
#    1902 raise AssertionError(op)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1882, in run_node(tracer, node, args, kwargs, nnmodule)
#    1881 elif op == "call_method":
# -> 1882     return getattr(args[0], node.target)(*args[1:], **kwargs)
#    1883 elif op == "call_module":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1557, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1556     with self:
# -> 1557         return decomposition_table[func](*args, **kwargs)
#    1559 with self:
#    1560     # Decomposes CompositeImplicitAutograd ops
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_refs/__init__.py:2933, in expand(a, *shape)
#    2931 requested_length = shape[offset_idx]
#    2932 torch._check(
# -> 2933     guard_size_oblivious(requested_length == x)
#    2934     or guard_size_oblivious(x == 1)
#    2935     or requested_length == -1,
#    2936     lambda: f"expand: attempting to expand a dimension of length {x}!",
#    2937 )
#    2939 shape_[offset_idx] = requested_length if requested_length != -1 else x
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# RuntimeError: Failed running call_method expand(*(FakeTensor(..., size=(8, 1)), -1, FakeTensor(..., size=(), dtype=torch.int64)), **{}):
# Could not guard on data-dependent expression Eq(u0, 1) (unhinted: Eq(u0, 1)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_refs/__init__.py", line 2933, in expand
#     guard_size_oblivious(requested_length == x)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1195362613.py", line 5, in cf_nomemo
#     return x.unsqueeze(1).expand(-1, y[0])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8         torch._check_is_size(u0)
#       9         return x.unsqueeze(1).expand(-1, u0)
#      11 @run_test
# ---> 12 def test_nomemo():
#      13     cf_nomemo(torch.randn(8), torch.tensor([2]))
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[7], line 13, in test_nomemo()
#      11 @run_test
#      12 def test_nomemo():
# ---> 13     cf_nomemo(torch.randn(8), torch.tensor([2]))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:1253, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1251 args = self.popn(inst.argval)
#    1252 fn = self.pop()
# -> 1253 self.call_function(fn, args, {})
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:737, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     735 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     736     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 737 self.push(fn.call_function(self, args, kwargs))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/misc.py:655, in GetAttrVariable.call_function(self, tx, args, kwargs)
#     652 def call_function(
#     653     self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#     654 ) -> "VariableTracker":
# --> 655     return self.obj.call_method(tx, self.name, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:457, in TensorVariable.call_method(self, tx, name, args, kwargs)
#     453         unimplemented(f"unhandled args for {name}: {e}")
#     455 from .builder import wrap_fx_proxy
# --> 457 return wrap_fx_proxy(
#     458     tx,
#     459     tx.output.create_proxy(
#     460         "call_method",
#     461         name,
#     462         *proxy_args_kwargs([self, *args], kwargs),
#     463     ),
#     464 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1519, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1511 kwargs = {
#    1512     "tx": tx,
#    1513     "proxy": proxy,
#    (...)
#    1516     **options,
#    1517 }
#    1518 if subclass_type is None:
# -> 1519     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1520 else:
#    1521     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1604, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1600 # with preserve_rng_state():
#    1601 if example_value is None:
#    1602     # only allow_non_graph_fake in this instance because we handle the non-fake
#    1603     # cases properly below.
# -> 1604     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1606 # Handle recursive calls here
#    1607 elif maybe_get_fake_mode(example_value) is tx.fake_mode:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1817, in get_fake_value(node, tx, allow_non_graph_fake)
#    1809     unimplemented(
#    1810         f"unsupported operator: {cause.func} ({import_suggestion}see "
#    1811         "https://docs.google.com/document/d/1GgvOe7C8_NVOMLOCwDaYV1mXXyHMXY7ExoewHqooxrs/edit#heading=h.64r4npvq0w0"
#    1812         " for how to fix)"
#    1813     )
#    1814 elif isinstance(
#    1815     cause, torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode
#    1816 ):
# -> 1817     raise UserError(  # noqa: TRY200
#    1818         UserErrorType.CONSTRAINT_VIOLATION,
#    1819         "Tried to use data-dependent value in the subsequent computation. "
#    1820         "This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  "
#    1821         "You will need to explicitly give hint to the compiler. Please take a look at "
#    1822         f"torch._check OR torch._check_is_size APIs.  {cause}",
#    1823         case_name="constrain_as_size_example",
#    1824     )
#    1825 elif isinstance(cause, ValueRangeError):
#    1826     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
#
# UserError: Tried to use data-dependent value in the subsequent computation. This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  You will need to explicitly give hint to the compiler. Please take a look at torch._check OR torch._check_is_size APIs.  Could not guard on data-dependent expression Eq(u0, 1) (unhinted: Eq(u0, 1)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_refs/__init__.py", line 2933, in expand
#     guard_size_oblivious(requested_length == x)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1195362613.py", line 5, in cf_nomemo
#     return x.unsqueeze(1).expand(-1, y[0])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/1195362613.py", line 5, in cf_nomemo
#     return x.unsqueeze(1).expand(-1, y[0])
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# ## What's in a tensor constructor?
#
# The very first guards you are likely to encounter with data-dependent shapes are those associated with tensor constructors.  Modern PyTorch has been patched to work with data-dependent shapes; in this section, we reimplement various important functions that are called during tensor construction, to make them data-dependent shape friendly.  If you don't feel comfortable working with strides, consider reading the [PyTorch Internals](http://blog.ezyang.com/2019/05/pytorch-internals/) blog post.  We have already imported `guard_size_oblivious` so that it is in scope.

# %% [markdown]
# **[contigstride]**  When you call a constructor like torch.empty() which produces a contiguous tensor, we must compute the contiguous strides for the tensor. Intuitively, the stride of a contiguous tensor is the product of all sizes to the left of it; e.g., a tensor with size `[2, 3, 4]` has stride `[3*4, 4, 1]`.
#
# This calculation has a subtle special case for zero sized tensors (`t.numel() == 0`). Ordinarily, a stride tells us how much we must advance the physical pointer of a tensor to access the next element.  But in a zero element tensor, there is no next element: this means we could validly put whatever we want in the stride of a tensor.  The convention that Numpy and PyTorch have for this situation is, we compute the strides as normal, but if a size is zero, we treat it as if it had size one for the purpose of stride computation, preventing us from zeroing out any subsequent strides.
#
# Below, we've reproduced `make_contiguous_strides_for` function in PyTorch.  Modify it so that it works with data dependent sizes.

# %%
# Change this FUNCTION only
def make_contiguous_strides_for(shape: List[int]) -> List[int]:
    """Returns the strides of a contiguous tensor."""
    multiplier = 1 
    strides = []
    for l in reversed(shape):
        torch._check_is_size(l)
        strides.append(multiplier)
        if l >= 1:
            multiplier *= l

    return list(reversed(strides))

def f_contigstride(pxs):
    xs = unpack_sizes(pxs)
    return torch.empty_strided(xs, make_contiguous_strides_for(xs))

cf_contigstride = torch.compile(fullgraph=True, backend="eager")(f_contigstride)

@run_test
def test_contfor():
    inp1, ans1 = pack_sizes([U(2), U(3), U(4)]), (12, 4, 1)
    assert_eq(f_contigstride(inp1).stride(), ans1)
    assert_eq(cf_contigstride(inp1).stride(), ans1)

    inp2, ans2 = pack_sizes([U(2), U(0), U(4)]), (4, 4, 1)
    assert_eq(f_contigstride(inp2).stride(), ans2)
    # Extra credit: can you make this test pass?
    # assert_eq(cf_contfor(inp2).stride(), ans2)
# Out:
# 🎉 Correct! 🎉

# %% [markdown]
# **[manualcontig]** Another thing we must do on tensor construction is compute if it is contiguous or not.  Although a call to torch.empty is obviously contiguous, constructors like torch.empty_strided allow construction of tensors with arbitrary strides, so we need an algorithm `is_contiguous` that can take the sizes and strides of a tensor and determine if it is contiguous.
#
# Modify the function below so that it works with data dependent sizes.

# %%
# Change this FUNCTION only
def is_contiguous(a: Tensor) -> bool:
    if a.numel() < 2:
        return True

    expected_stride = 1
    for x, y in reversed(tuple(zip(a.shape, a.stride()))):
        # Skips checking strides when a dimension has length 1
        if x == 1:
            continue

        if y != expected_stride:
            return False
        expected_stride = expected_stride * x

    return True   

def f_manualcontig(x):
    return force_guard(is_contiguous(unpack_tensor(x)))

cf_manualcontig = torch.compile(fullgraph=True, backend="eager")(f_manualcontig)

@run_test
def test_manualcontig():
    inp1 = pack_sizes([U(2), U(3), U(4)])
    assert cf_manualcontig(inp1).item()
# Out:
# E0507 13:53:19.464771 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(u0*u1*u2 < 2, None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1001, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1000 try:
# -> 1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:748, in guard_scalar(a)
#     747 if isinstance(a, (SymBool, bool)):
# --> 748     return guard_bool(a)
#     749 elif isinstance(a, (SymInt, int)):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:921, in guard_bool(a)
#     920 if isinstance(a, SymBool):
# --> 921     return a.node.guard_bool("", 0)  # NB: uses Python backtrace
#     922 assert type(a) is bool, a
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression u0*u1*u2 < 2 (unhinted: u0*u1*u2 < 2).  (Size-like symbols: u1, u2, u0)
#
# ATTENTION: guard_size_oblivious would fix the error, evaluating expression to False.
# Maybe you need to add guard_size_oblivious to framework code, see doc below for more guidance.
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u1,u2,u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/31810881.py", line 19, in f_manualcontig
#     return force_guard(is_contiguous(unpack_tensor(x)))
#   File "/tmp/ipykernel_2254597/31810881.py", line 3, in is_contiguous
#     if a.numel() < 2:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[10], line 24
#      19     return force_guard(is_contiguous(unpack_tensor(x)))
#      21 cf_manualcontig = torch.compile(fullgraph=True, backend="eager")(f_manualcontig)
#      23 @run_test
# ---> 24 def test_manualcontig():
#      25     inp1 = pack_sizes([U(2), U(3), U(4)])
#      26     assert cf_manualcontig(inp1).item()
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[10], line 26, in test_manualcontig()
#      23 @run_test
#      24 def test_manualcontig():
#      25     inp1 = pack_sizes([U(2), U(3), U(4)])
# ---> 26     assert cf_manualcontig(inp1).item()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:1253, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1251 args = self.popn(inst.argval)
#    1252 fn = self.pop()
# -> 1253 self.call_function(fn, args, {})
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:737, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     735 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     736     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 737 self.push(fn.call_function(self, args, kwargs))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:293, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     288 if self.is_constant:
#     289     return invoke_and_store_as_constant(
#     290         tx, self.fn, self.get_name(), args, kwargs
#     291     )
# --> 293 return super().call_function(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:90, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#      87 def call_function(
#      88     self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      89 ) -> "VariableTracker":
# ---> 90     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:743, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     739 def inline_user_function_return(self, fn, args, kwargs):
#     740     """
#     741     A call to some user defined function by inlining it.
#     742     """
# --> 743     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2448, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    2445 @classmethod
#    2446 def inline_call(cls, parent, func, args, kwargs):
#    2447     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2448         return cls.inline_call_(parent, func, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2564, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    2562 try:
#    2563     with strict_ctx:
# -> 2564         tracer.run()
#    2565 except exc.SkipFrame as e:
#    2566     msg = f"SKIPPED INLINING {code}: {e}"
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:448, in generic_jump.<locals>.inner(self, inst)
#     446 elif isinstance(value, SymNodeVariable):
#     447     try:
# --> 448         eval_result = value.evaluate_expr(self.output)
#     449     except exc.UserError as e:
#     450         if self.should_compile_partial_graph():
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1003, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
# -> 1003     raise UserError(  # noqa: TRY200
#    1004         UserErrorType.ANTI_PATTERN,
#    1005         f"Consider annotating your code using torch._check*(). {str(e)}",
#    1006         case_name="constrain_as_size_example",
#    1007     )
#
# UserError: Consider annotating your code using torch._check*(). Could not guard on data-dependent expression u0*u1*u2 < 2 (unhinted: u0*u1*u2 < 2).  (Size-like symbols: u1, u2, u0)
#
# ATTENTION: guard_size_oblivious would fix the error, evaluating expression to False.
# Maybe you need to add guard_size_oblivious to framework code, see doc below for more guidance.
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u1,u2,u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/31810881.py", line 19, in f_manualcontig
#     return force_guard(is_contiguous(unpack_tensor(x)))
#   File "/tmp/ipykernel_2254597/31810881.py", line 3, in is_contiguous
#     if a.numel() < 2:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/31810881.py", line 19, in f_manualcontig
#     return force_guard(is_contiguous(unpack_tensor(x)))
#   File "/tmp/ipykernel_2254597/31810881.py", line 3, in is_contiguous
#     if a.numel() < 2:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[transposecontig]** In PyTorch, `is_contiguous` is implemented with `guard_size_oblivious`.  The use of guard_size_oblivous means that sometimes the semantics of plain and compiled programs can diverge.  The most obvious consequence of this is that with unbacked SymInts, we will generally conclude that tensors are noncontiguous, even if there are specific values for which they might actually be contiguous.  For example, we always consider a transposed 2D tensor of size `[u0, u1]` non-contiguous.
#
# In the test below, change `inp1` to show a 2D tensor which is contiguous in eager mode even after transposition.

# %%
def f_transposecontig(sizes):
    x = torch.zeros(sizes.tolist()).T
    return force_guard(x.is_contiguous())

cf_transposecontig = torch.compile(fullgraph=True, backend="eager")(f_transposecontig)

@run_test
def test_transposecontig():
    # Change the int values in pack_sizes ONLY
    inp1 = torch.tensor([3, 4])

    assert not torch.allclose(f_transposecontig(inp1), cf_transposecontig(inp1)), f"{f_transposecontig(inp1)} == {cf_transposecontig(inp1)}"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 8
#       3     return force_guard(x.is_contiguous())
#       5 cf_transposecontig = torch.compile(fullgraph=True, backend="eager")(f_transposecontig)
#       7 @run_test
# ----> 8 def test_transposecontig():
#       9     # Change the int values in pack_sizes ONLY
#      10     inp1 = torch.tensor([3, 4])
#      12     assert not torch.allclose(f_transposecontig(inp1), cf_transposecontig(inp1)), f"{f_transposecontig(inp1)} == {cf_transposecontig(inp1)}"
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[22], line 12, in test_transposecontig()
#       7 @run_test
#       8 def test_transposecontig():
#       9     # Change the int values in pack_sizes ONLY
#      10     inp1 = torch.tensor([3, 4])
# ---> 12     assert not torch.allclose(f_transposecontig(inp1), cf_transposecontig(inp1)), f"{f_transposecontig(inp1)} == {cf_transposecontig(inp1)}"
#
# AssertionError: False == False

# %% [markdown]
# A similar version of the problem above also occurs when answering `is_contiguous(memory_format=torch.channels_last)`, since NCHW contiguous (the default) tensors are typically not NHWC contiguous, except under the same conditions as the input above.

# %% [markdown]
# ## Pointwise operations: broadcasting
#
# Whenever you perform a pointwise operation between two tensors, we must compute the output shape of the tensor. Because PyTorch supports implicit broadcasting, this is not simply "assert the two input tensors have the same size and produce a tensor of the same size."  Instead, whenever you compare two dimensions for equality, you allow for a size mismatch if one of the dimensions is size one.  Unlike the previous examples, you will need to make more changes than just slapping `guard_size_oblivious` on the conditions.

# %%
def infer_size(a: List[int], b: List[int]) -> List[int]:
    dimsA = len(a)
    dimsB = len(b)
    ndim = max(dimsA, dimsB)
    expandedSizes = [0] * ndim
    for i in range(ndim - 1, -1, -1):
        offset = ndim - 1 - i
        dimA = dimsA - 1 - offset
        dimB = dimsB - 1 - offset
        sizeA = a[dimA] if dimA >= 0 else 1
        sizeB = b[dimB] if dimB >= 0 else 1
        torch._check_is_size(sizeA)
        torch._check_is_size(sizeB)
        if sizeA == sizeB:
            expandedSizes[i] = sizeA
        elif sizeA == 1:
            expandedSizes[i] = sizeB
        elif sizeB == 1:
            expandedSizes[i] = sizeA
        else:
            raise RuntimeError("shape mismatch")
    return expandedSizes

def f_infersize(sz1, sz2):
    return torch.zeros(infer_size(unpack_sizes(sz1), unpack_sizes(sz2)))

cf_infersize = torch.compile(fullgraph=True, backend="eager")(f_infersize)

@run_test
def test_infersize():
    # Some baseline tests: these should pass even without changes
    assert_eq(cf_infersize(pack_sizes([2, 3, 4]), pack_sizes([2, 3, 4])).shape, torch.Size([2, 3, 4]))
    assert_eq(cf_infersize(pack_sizes([2, 1, 4]), pack_sizes([2, 3, 4])).shape, torch.Size([2, 3, 4]))
    # Now test with unbacked SymInts
    assert_eq(cf_infersize(pack_sizes([2, 1, 4]), pack_sizes([2, U(3), 4])).shape, torch.Size([2, 3, 4]))
    # NB: The two occurrences of U(2) have distinct unbacked SymInts!
    assert_eq(cf_infersize(pack_sizes([U(2), 1, 4]), pack_sizes([U(2), U(3), 4])).shape, torch.Size([2, 3, 4]))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 30
#      25     return torch.zeros(infer_size(unpack_sizes(sz1), unpack_sizes(sz2)))
#      27 cf_infersize = torch.compile(fullgraph=True, backend="eager")(f_infersize)
#      29 @run_test
# ---> 30 def test_infersize():
#      31     # Some baseline tests: these should pass even without changes
#      32     assert_eq(cf_infersize(pack_sizes([2, 3, 4]), pack_sizes([2, 3, 4])).shape, (2, 3, 4))
#      33     assert_eq(cf_infersize(pack_sizes([2, 1, 4]), pack_sizes([2, 3, 4])).shape, (2, 3, 4))
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[12], line 32, in test_infersize()
#      29 @run_test
#      30 def test_infersize():
#      31     # Some baseline tests: these should pass even without changes
# ---> 32     assert_eq(cf_infersize(pack_sizes([2, 3, 4]), pack_sizes([2, 3, 4])).shape, (2, 3, 4))
#      33     assert_eq(cf_infersize(pack_sizes([2, 1, 4]), pack_sizes([2, 3, 4])).shape, (2, 3, 4))
#      34     # Now test with unbacked SymInts
#
# Cell In[2], line 27, in assert_eq(actual, expected)
#      25     cond = len(actual) == len(expected)
#      26 else:
# ---> 27     assert type(actual) == type(expected), (actual, expected)
#      28     cond = actual == expected
#      29     assert isinstance(cond, bool), (actual, expected)
#
# AssertionError: (torch.Size([2, 3, 4]), (2, 3, 4))

# %% [markdown]
# ## More advanced symbolic reasoning
#
# **[latespec]** Reasoning about guards is done *online* fashion; whenever we have to test a guard, we must immediately determine if it is true or false; otherwise tracing cannot continue.  This means that whether or not a program traces is order sensitive.
#
# Without removing the guard in question or adding any deferred runtime asserts to u0, modify this program so it compiles.

# %%
@torch.compile(dynamic=True, fullgraph=True, backend="eager")
def cf_latespec(x, y):
    u0 = unpack_size(x)
    s0 = y.size(0)
    b = force_guard(u0 * s0 ** 2 == 9 * u0)  # do not change this line
    torch._check(s0 == 3)
    return b

@run_test
def test_latespec():
    assert cf_latespec(pack_size(U(10)), torch.randn(3)).item()
# Out:
# E0507 13:53:51.784919 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq(s0**2*u0, 9*u0), True), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1001, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1000 try:
# -> 1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:748, in guard_scalar(a)
#     747 if isinstance(a, (SymBool, bool)):
# --> 748     return guard_bool(a)
#     749 elif isinstance(a, (SymInt, int)):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:921, in guard_bool(a)
#     920 if isinstance(a, SymBool):
# --> 921     return a.node.guard_bool("", 0)  # NB: uses Python backtrace
#     922 assert type(a) is bool, a
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression True (unhinted: Eq(s0**2*u0, 9*u0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL=""
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/3342081866.py", line 5, in cf_latespec
#     b = force_guard(u0 * s0 ** 2 == 9 * u0)  # do not change this line
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       6     torch._check(s0 == 3)
#       7     return b
#       9 @run_test
# ---> 10 def test_latespec():
#      11     assert cf_latespec(pack_size(U(10)), torch.randn(3)).item()
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[13], line 11, in test_latespec()
#       9 @run_test
#      10 def test_latespec():
# ---> 11     assert cf_latespec(pack_size(U(10)), torch.randn(3)).item()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:1253, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1251 args = self.popn(inst.argval)
#    1252 fn = self.pop()
# -> 1253 self.call_function(fn, args, {})
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:737, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     735 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     736     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 737 self.push(fn.call_function(self, args, kwargs))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:293, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     288 if self.is_constant:
#     289     return invoke_and_store_as_constant(
#     290         tx, self.fn, self.get_name(), args, kwargs
#     291     )
# --> 293 return super().call_function(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:90, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#      87 def call_function(
#      88     self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      89 ) -> "VariableTracker":
# ---> 90     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:743, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     739 def inline_user_function_return(self, fn, args, kwargs):
#     740     """
#     741     A call to some user defined function by inlining it.
#     742     """
# --> 743     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2448, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    2445 @classmethod
#    2446 def inline_call(cls, parent, func, args, kwargs):
#    2447     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2448         return cls.inline_call_(parent, func, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2564, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    2562 try:
#    2563     with strict_ctx:
# -> 2564         tracer.run()
#    2565 except exc.SkipFrame as e:
#    2566     msg = f"SKIPPED INLINING {code}: {e}"
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:448, in generic_jump.<locals>.inner(self, inst)
#     446 elif isinstance(value, SymNodeVariable):
#     447     try:
# --> 448         eval_result = value.evaluate_expr(self.output)
#     449     except exc.UserError as e:
#     450         if self.should_compile_partial_graph():
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1003, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
# -> 1003     raise UserError(  # noqa: TRY200
#    1004         UserErrorType.ANTI_PATTERN,
#    1005         f"Consider annotating your code using torch._check*(). {str(e)}",
#    1006         case_name="constrain_as_size_example",
#    1007     )
#
# UserError: Consider annotating your code using torch._check*(). Could not guard on data-dependent expression True (unhinted: Eq(s0**2*u0, 9*u0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL=""
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/3342081866.py", line 5, in cf_latespec
#     b = force_guard(u0 * s0 ** 2 == 9 * u0)  # do not change this line
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/3342081866.py", line 5, in cf_latespec
#     b = force_guard(u0 * s0 ** 2 == 9 * u0)  # do not change this line
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[uselessunbacked]** Sometimes, poorly written user code reads out unbacked variables from Tensors for use with sizes, even when they actually statically *know* the size in question.  Rewriting code to preferentially used backed quantities, and only referencing unbacked code to generate runtime asserts, can help you bypass data dependent exceptions.
#
# Without changing the runtime semantics (including exception throwing behavior), modify this program so it compiles.

# %%
# TODO: Inductor still seems to be dropping the asserts :think:
@torch.compile(dynamic=True, fullgraph=True, backend="eager")
def cf_uselessunbacked(x, y):
    u0 = unpack_size(x)
    x2 = torch.arange(u0 // 2)
    return x2 + y

@run_test
def test_uselessunbacked():
    assert_eq(cf_uselessunbacked(pack_size(U(20)), torch.zeros(10, dtype=torch.int64)), torch.arange(10,))
    try:
        cf_uselessunbacked(pack_size(U(10)), torch.zeros(10, dtype=torch.int64))
    except RuntimeError:
        pass
    else:
        raise AssertionError("Expected runtime error")
# Out:
# E0507 13:53:59.362569 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq((u0//2), 1), None), **{'fx_node': None, 'size_oblivious': True})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1538, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1537     if fast_impl is not None:
# -> 1538         return maybe_propagate_real_tensors(fast_impl(self, *args, **kwargs))
#    1540 # If there's a Python meta, prefer that over the decomposition
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:1010, in make_fast_binary_impl.<locals>.fast_binary_impl(mode, *args, **kwargs)
#    1007     # TODO: Minor optimization: track if the shapes
#    1008     # were equal so you can skip the equality check
#    1009     # below if unnecessary
# -> 1010     final_shape = infer_size(final_shape, shape)
#    1011 assert final_shape is not None
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:965, in infer_size(a, b)
#     953 # NB: It is very important to test for broadcasting, before testing
#     954 # sizeA == sizeB.  This is because the broadcasting tests are likely
#     955 # to be statically known (in particular, if sizeA/sizeB is unbacked
#    (...)
#     962 # were not the case, we'd need to write this using torch.sym_or() or
#     963 # something like that).
#     964 torch._check(
# --> 965     guard_size_oblivious(sizeA == 1)
#     966     or guard_size_oblivious(sizeB == 1)
#     967     or sizeA == sizeB,
#     968     lambda: f"The size of tensor a ({sizeA}) "
#     969     f"must match the size of tensor b ({sizeB}) "
#     970     f"at non-singleton dimension {i})",
#     971 )
#     972 expandedSizes[i] = sizeB if guard_size_oblivious(sizeA == 1) else sizeA
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/8438927.py", line 6, in cf_uselessunbacked
#     return x2 + y
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1762, in get_fake_value(node, tx, allow_non_graph_fake)
#    1761     with tx.fake_mode, enable_python_dispatcher():
# -> 1762         ret_val = wrap_fake_exception(
#    1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1277, in wrap_fake_exception(fn)
#    1276 try:
# -> 1277     return fn()
#    1278 except UnsupportedFakeTensorException as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1763, in get_fake_value.<locals>.<lambda>()
#    1761     with tx.fake_mode, enable_python_dispatcher():
#    1762         ret_val = wrap_fake_exception(
# -> 1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1898, in run_node(tracer, node, args, kwargs, nnmodule)
#    1897     except Exception as e:
# -> 1898         raise RuntimeError(make_error_message(e)).with_traceback(
#    1899             e.__traceback__
#    1900         ) from e
#    1902 raise AssertionError(op)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1538, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1537     if fast_impl is not None:
# -> 1538         return maybe_propagate_real_tensors(fast_impl(self, *args, **kwargs))
#    1540 # If there's a Python meta, prefer that over the decomposition
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:1010, in make_fast_binary_impl.<locals>.fast_binary_impl(mode, *args, **kwargs)
#    1007     # TODO: Minor optimization: track if the shapes
#    1008     # were equal so you can skip the equality check
#    1009     # below if unnecessary
# -> 1010     final_shape = infer_size(final_shape, shape)
#    1011 assert final_shape is not None
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:965, in infer_size(a, b)
#     953 # NB: It is very important to test for broadcasting, before testing
#     954 # sizeA == sizeB.  This is because the broadcasting tests are likely
#     955 # to be statically known (in particular, if sizeA/sizeB is unbacked
#    (...)
#     962 # were not the case, we'd need to write this using torch.sym_or() or
#     963 # something like that).
#     964 torch._check(
# --> 965     guard_size_oblivious(sizeA == 1)
#     966     or guard_size_oblivious(sizeB == 1)
#     967     or sizeA == sizeB,
#     968     lambda: f"The size of tensor a ({sizeA}) "
#     969     f"must match the size of tensor b ({sizeB}) "
#     970     f"at non-singleton dimension {i})",
#     971 )
#     972 expandedSizes[i] = sizeB if guard_size_oblivious(sizeA == 1) else sizeA
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# RuntimeError: Failed running call_function <built-in function add>(*(FakeTensor(..., size=((u0//2),), dtype=torch.int64), FakeTensor(..., size=(s0,), dtype=torch.int64)), **{}):
# Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/8438927.py", line 6, in cf_uselessunbacked
#     return x2 + y
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       5     x2 = torch.arange(u0 // 2)
#       6     return x2 + y
#       8 @run_test
# ----> 9 def test_uselessunbacked():
#      10     assert_eq(cf_uselessunbacked(pack_size(U(20)), torch.zeros(10, dtype=torch.int64)), torch.arange(10,))
#      11     try:
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[14], line 10, in test_uselessunbacked()
#       8 @run_test
#       9 def test_uselessunbacked():
# ---> 10     assert_eq(cf_uselessunbacked(pack_size(U(20)), torch.zeros(10, dtype=torch.int64)), torch.arange(10,))
#      11     try:
#      12         cf_uselessunbacked(pack_size(U(10)), torch.zeros(10, dtype=torch.int64))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:231, in stack_op.<locals>.impl(self, inst)
#     229 @functools.wraps(fn)
#     230 def impl(self: "InstructionTranslatorBase", inst: Instruction):
# --> 231     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:711, in BuiltinVariable._make_handler.<locals>.<lambda>(tx, args, kwargs)
#     708 handlers = []
#     710 if any(issubclass(t, LazyVariableTracker) for t in arg_types):
# --> 711     return lambda tx, args, kwargs: obj.call_function(
#     712         tx, [v.realize() for v in args], kwargs
#     713     )
#     715 if obj.can_insert_in_graph() and not (
#     716     fn is operator.getitem
#     717     and not issubclass(arg_types[0], variables.TensorVariable)
#     718 ):
#     719     if obj.tensor_args_type(arg_types):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:925, in BuiltinVariable._handle_insert_op_in_graph(self, tx, args, kwargs)
#     921         if fn is operator.truediv and isinstance(
#     922             args[0], variables.UnspecializedPythonVariable
#     923         ):
#     924             args[0] = args[0].convert_to_constant(tx)
# --> 925         return wrap_fx_proxy(tx, proxy)
#     927 except NotImplementedError:
#     928     unimplemented(f"partial tensor op: {self} {args} {kwargs}")
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1519, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1511 kwargs = {
#    1512     "tx": tx,
#    1513     "proxy": proxy,
#    (...)
#    1516     **options,
#    1517 }
#    1518 if subclass_type is None:
# -> 1519     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1520 else:
#    1521     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1604, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1600 # with preserve_rng_state():
#    1601 if example_value is None:
#    1602     # only allow_non_graph_fake in this instance because we handle the non-fake
#    1603     # cases properly below.
# -> 1604     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1606 # Handle recursive calls here
#    1607 elif maybe_get_fake_mode(example_value) is tx.fake_mode:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1817, in get_fake_value(node, tx, allow_non_graph_fake)
#    1809     unimplemented(
#    1810         f"unsupported operator: {cause.func} ({import_suggestion}see "
#    1811         "https://docs.google.com/document/d/1GgvOe7C8_NVOMLOCwDaYV1mXXyHMXY7ExoewHqooxrs/edit#heading=h.64r4npvq0w0"
#    1812         " for how to fix)"
#    1813     )
#    1814 elif isinstance(
#    1815     cause, torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode
#    1816 ):
# -> 1817     raise UserError(  # noqa: TRY200
#    1818         UserErrorType.CONSTRAINT_VIOLATION,
#    1819         "Tried to use data-dependent value in the subsequent computation. "
#    1820         "This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  "
#    1821         "You will need to explicitly give hint to the compiler. Please take a look at "
#    1822         f"torch._check OR torch._check_is_size APIs.  {cause}",
#    1823         case_name="constrain_as_size_example",
#    1824     )
#    1825 elif isinstance(cause, ValueRangeError):
#    1826     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
#
# UserError: Tried to use data-dependent value in the subsequent computation. This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  You will need to explicitly give hint to the compiler. Please take a look at torch._check OR torch._check_is_size APIs.  Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/8438927.py", line 6, in cf_uselessunbacked
#     return x2 + y
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/8438927.py", line 6, in cf_uselessunbacked
#     return x2 + y
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[changevar]** When you call item() on a tensor, you trigger the allocation of a fresh unbacked variable.  It matters whether or not a given size is a variable `u0` or an expression `u0 // 2`, because we only ascribe value ranges to variables; expressions only ever have their value ranges derived from the value ranges of their free symbols.
#
# Without changing the valid range of values for x, modify the program below so that it compiles.

# %%
@torch.compile(dynamic=True, fullgraph=True, backend="eager")
def cf_changevar(x):
    u0 = x.item()
    torch._check_is_size(u0)
    r = torch.arange(u0 // 2)
    return r + r

@run_test
def test_changevar():
    assert_eq(cf_changevar(torch.tensor(20)), torch.arange(10) * 2)
    assert_eq(cf_changevar(torch.tensor(0)), torch.arange(0) * 2)
# Out:
# E0507 13:54:07.374292 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq((u0//2), 1), None), **{'fx_node': None, 'size_oblivious': True})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1538, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1537     if fast_impl is not None:
# -> 1538         return maybe_propagate_real_tensors(fast_impl(self, *args, **kwargs))
#    1540 # If there's a Python meta, prefer that over the decomposition
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:1010, in make_fast_binary_impl.<locals>.fast_binary_impl(mode, *args, **kwargs)
#    1007     # TODO: Minor optimization: track if the shapes
#    1008     # were equal so you can skip the equality check
#    1009     # below if unnecessary
# -> 1010     final_shape = infer_size(final_shape, shape)
#    1011 assert final_shape is not None
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:965, in infer_size(a, b)
#     953 # NB: It is very important to test for broadcasting, before testing
#     954 # sizeA == sizeB.  This is because the broadcasting tests are likely
#     955 # to be statically known (in particular, if sizeA/sizeB is unbacked
#    (...)
#     962 # were not the case, we'd need to write this using torch.sym_or() or
#     963 # something like that).
#     964 torch._check(
# --> 965     guard_size_oblivious(sizeA == 1)
#     966     or guard_size_oblivious(sizeB == 1)
#     967     or sizeA == sizeB,
#     968     lambda: f"The size of tensor a ({sizeA}) "
#     969     f"must match the size of tensor b ({sizeB}) "
#     970     f"at non-singleton dimension {i})",
#     971 )
#     972 expandedSizes[i] = sizeB if guard_size_oblivious(sizeA == 1) else sizeA
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/3898965675.py", line 6, in cf_changevar
#     return r + r
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1762, in get_fake_value(node, tx, allow_non_graph_fake)
#    1761     with tx.fake_mode, enable_python_dispatcher():
# -> 1762         ret_val = wrap_fake_exception(
#    1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1277, in wrap_fake_exception(fn)
#    1276 try:
# -> 1277     return fn()
#    1278 except UnsupportedFakeTensorException as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1763, in get_fake_value.<locals>.<lambda>()
#    1761     with tx.fake_mode, enable_python_dispatcher():
#    1762         ret_val = wrap_fake_exception(
# -> 1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1898, in run_node(tracer, node, args, kwargs, nnmodule)
#    1897     except Exception as e:
# -> 1898         raise RuntimeError(make_error_message(e)).with_traceback(
#    1899             e.__traceback__
#    1900         ) from e
#    1902 raise AssertionError(op)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1538, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1537     if fast_impl is not None:
# -> 1538         return maybe_propagate_real_tensors(fast_impl(self, *args, **kwargs))
#    1540 # If there's a Python meta, prefer that over the decomposition
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:1010, in make_fast_binary_impl.<locals>.fast_binary_impl(mode, *args, **kwargs)
#    1007     # TODO: Minor optimization: track if the shapes
#    1008     # were equal so you can skip the equality check
#    1009     # below if unnecessary
# -> 1010     final_shape = infer_size(final_shape, shape)
#    1011 assert final_shape is not None
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py:965, in infer_size(a, b)
#     953 # NB: It is very important to test for broadcasting, before testing
#     954 # sizeA == sizeB.  This is because the broadcasting tests are likely
#     955 # to be statically known (in particular, if sizeA/sizeB is unbacked
#    (...)
#     962 # were not the case, we'd need to write this using torch.sym_or() or
#     963 # something like that).
#     964 torch._check(
# --> 965     guard_size_oblivious(sizeA == 1)
#     966     or guard_size_oblivious(sizeB == 1)
#     967     or sizeA == sizeB,
#     968     lambda: f"The size of tensor a ({sizeA}) "
#     969     f"must match the size of tensor b ({sizeB}) "
#     970     f"at non-singleton dimension {i})",
#     971 )
#     972 expandedSizes[i] = sizeB if guard_size_oblivious(sizeA == 1) else sizeA
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:241, in guard_size_oblivious(expr)
#     240 if isinstance(expr, torch.SymBool):
# --> 241     return expr.node.guard_size_oblivious("", 0)
#     242 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:429, in SymNode.guard_size_oblivious(self, file, line)
#     427 # TODO: use the file/line for some useful diagnostic on why a
#     428 # guard occurred
# --> 429 r = self.shape_env.evaluate_expr(
#     430     self.expr, self.hint, fx_node=self.fx_node, size_oblivious=True
#     431 )
#     432 try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# RuntimeError: Failed running call_function <built-in function add>(*(FakeTensor(..., size=((u0//2),), dtype=torch.int64), FakeTensor(..., size=((u0//2),), dtype=torch.int64)), **{}):
# Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/3898965675.py", line 6, in cf_changevar
#     return r + r
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       5     r = torch.arange(u0 // 2)
#       6     return r + r
#       8 @run_test
# ----> 9 def test_changevar():
#      10     assert_eq(cf_changevar(torch.tensor(20)), torch.arange(10) * 2)
#      11     assert_eq(cf_changevar(torch.tensor(0)), torch.arange(0) * 2)
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[15], line 10, in test_changevar()
#       8 @run_test
#       9 def test_changevar():
# ---> 10     assert_eq(cf_changevar(torch.tensor(20)), torch.arange(10) * 2)
#      11     assert_eq(cf_changevar(torch.tensor(0)), torch.arange(0) * 2)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:231, in stack_op.<locals>.impl(self, inst)
#     229 @functools.wraps(fn)
#     230 def impl(self: "InstructionTranslatorBase", inst: Instruction):
# --> 231     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:925, in BuiltinVariable._handle_insert_op_in_graph(self, tx, args, kwargs)
#     921         if fn is operator.truediv and isinstance(
#     922             args[0], variables.UnspecializedPythonVariable
#     923         ):
#     924             args[0] = args[0].convert_to_constant(tx)
# --> 925         return wrap_fx_proxy(tx, proxy)
#     927 except NotImplementedError:
#     928     unimplemented(f"partial tensor op: {self} {args} {kwargs}")
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1519, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1511 kwargs = {
#    1512     "tx": tx,
#    1513     "proxy": proxy,
#    (...)
#    1516     **options,
#    1517 }
#    1518 if subclass_type is None:
# -> 1519     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1520 else:
#    1521     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1604, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1600 # with preserve_rng_state():
#    1601 if example_value is None:
#    1602     # only allow_non_graph_fake in this instance because we handle the non-fake
#    1603     # cases properly below.
# -> 1604     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1606 # Handle recursive calls here
#    1607 elif maybe_get_fake_mode(example_value) is tx.fake_mode:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1817, in get_fake_value(node, tx, allow_non_graph_fake)
#    1809     unimplemented(
#    1810         f"unsupported operator: {cause.func} ({import_suggestion}see "
#    1811         "https://docs.google.com/document/d/1GgvOe7C8_NVOMLOCwDaYV1mXXyHMXY7ExoewHqooxrs/edit#heading=h.64r4npvq0w0"
#    1812         " for how to fix)"
#    1813     )
#    1814 elif isinstance(
#    1815     cause, torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode
#    1816 ):
# -> 1817     raise UserError(  # noqa: TRY200
#    1818         UserErrorType.CONSTRAINT_VIOLATION,
#    1819         "Tried to use data-dependent value in the subsequent computation. "
#    1820         "This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  "
#    1821         "You will need to explicitly give hint to the compiler. Please take a look at "
#    1822         f"torch._check OR torch._check_is_size APIs.  {cause}",
#    1823         case_name="constrain_as_size_example",
#    1824     )
#    1825 elif isinstance(cause, ValueRangeError):
#    1826     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
#
# UserError: Tried to use data-dependent value in the subsequent computation. This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  You will need to explicitly give hint to the compiler. Please take a look at torch._check OR torch._check_is_size APIs.  Could not guard on data-dependent expression Eq((u0//2), 1) (unhinted: Eq((u0//2), 1)).  (Size-like symbols: u0)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_impls.py", line 965, in infer_size
#     guard_size_oblivious(sizeA == 1)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/3898965675.py", line 6, in cf_changevar
#     return r + r
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/3898965675.py", line 6, in cf_changevar
#     return r + r
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[varrange]** Value ranges are a simple but powerful reasoning mechanism, whereby we propagate the lower and upper bounds of variables through expressions.  When you perform a `torch._check(u0 >= c)`, where c is a constant, you refine the value range of that variable.
#
# Using only one call to `torch._check` (do NOT use `torch._check_is_size`), discharge all of the guards in this program.

# %%
@torch.compile(dynamic=True, fullgraph=True, backend="eager")
def cf_varrange(x):
    u0 = x.item()
    # Put your torch._check call here
    pass
    a = force_guard(u0 != 0)
    b = force_guard(u0 != 1)
    c = force_guard(u0 != -1)
    d = force_guard(u0 * u0 != 0)
    e = force_guard(u0 >= 0)
    f = force_guard(u0 * u0 >= 2)
    return sum([a, b, c, d, e, f])

@run_test
def test_varrange():
    assert cf_varrange(torch.tensor(2)).item() == 6
    assert cf_varrange(torch.tensor(10)).item() == 6
    assert cf_varrange(torch.tensor(100)).item() == 6
# Out:
# E0507 13:54:13.982693 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Ne(u0, 0), None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1001, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1000 try:
# -> 1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:748, in guard_scalar(a)
#     747 if isinstance(a, (SymBool, bool)):
# --> 748     return guard_bool(a)
#     749 elif isinstance(a, (SymInt, int)):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:921, in guard_bool(a)
#     920 if isinstance(a, SymBool):
# --> 921     return a.node.guard_bool("", 0)  # NB: uses Python backtrace
#     922 assert type(a) is bool, a
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Ne(u0, 0) (unhinted: Ne(u0, 0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/705518948.py", line 6, in cf_varrange
#     a = force_guard(u0 != 0)
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[16], line 15
#      11     f = force_guard(u0 * u0 >= 2)
#      12     return sum([a, b, c, d, e, f])
#      14 @run_test
# ---> 15 def test_varrange():
#      16     assert cf_varrange(torch.tensor(2)).item() == 6
#      17     assert cf_varrange(torch.tensor(10)).item() == 6
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[16], line 16, in test_varrange()
#      14 @run_test
#      15 def test_varrange():
# ---> 16     assert cf_varrange(torch.tensor(2)).item() == 6
#      17     assert cf_varrange(torch.tensor(10)).item() == 6
#      18     assert cf_varrange(torch.tensor(100)).item() == 6
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:1253, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1251 args = self.popn(inst.argval)
#    1252 fn = self.pop()
# -> 1253 self.call_function(fn, args, {})
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:737, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     735 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     736     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 737 self.push(fn.call_function(self, args, kwargs))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:293, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     288 if self.is_constant:
#     289     return invoke_and_store_as_constant(
#     290         tx, self.fn, self.get_name(), args, kwargs
#     291     )
# --> 293 return super().call_function(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/functions.py:90, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#      87 def call_function(
#      88     self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      89 ) -> "VariableTracker":
# ---> 90     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:743, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     739 def inline_user_function_return(self, fn, args, kwargs):
#     740     """
#     741     A call to some user defined function by inlining it.
#     742     """
# --> 743     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2448, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    2445 @classmethod
#    2446 def inline_call(cls, parent, func, args, kwargs):
#    2447     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2448         return cls.inline_call_(parent, func, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2564, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    2562 try:
#    2563     with strict_ctx:
# -> 2564         tracer.run()
#    2565 except exc.SkipFrame as e:
#    2566     msg = f"SKIPPED INLINING {code}: {e}"
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:448, in generic_jump.<locals>.inner(self, inst)
#     446 elif isinstance(value, SymNodeVariable):
#     447     try:
# --> 448         eval_result = value.evaluate_expr(self.output)
#     449     except exc.UserError as e:
#     450         if self.should_compile_partial_graph():
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1003, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
# -> 1003     raise UserError(  # noqa: TRY200
#    1004         UserErrorType.ANTI_PATTERN,
#    1005         f"Consider annotating your code using torch._check*(). {str(e)}",
#    1006         case_name="constrain_as_size_example",
#    1007     )
#
# UserError: Consider annotating your code using torch._check*(). Could not guard on data-dependent expression Ne(u0, 0) (unhinted: Ne(u0, 0)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/705518948.py", line 6, in cf_varrange
#     a = force_guard(u0 != 0)
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/705518948.py", line 6, in cf_varrange
#     a = force_guard(u0 != 0)
#   File "/tmp/ipykernel_2254597/3482625302.py", line 58, in force_guard
#     if x:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# ## Judo moves
#
# Sometimes, fixing your code doesn't involve just bashing `torch._check` everywhere, you need a more semantic change, a judo move.
#
# **[stacklist]** Unbacked SymInts cannot be used to index into Python data structures.  However, if the data structure can be expressed as a single Tensor, it can be done symbolically

# %%
@torch.compile(fullgraph=True, backend="eager")
def cf_stacklist(xs: List[Tensor], y: Tensor):
    u0 = y.item()
    torch._check_is_size(u0)
    torch._check(u0 < len(xs))
    return xs[u0]

@run_test
def test_stacklist():
    assert_eq(cf_stacklist([torch.zeros(5), torch.ones(5)], torch.tensor(0)), torch.zeros(5))
# Out:
# E0507 13:54:28.495733 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(u0, None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# Cell In[19], line 7
#       3     u0 = y.item()
#       4     return xs[u0]
#       6 @run_test
# ----> 7 def test_stacklist():
#       8     assert_eq(cf_stacklist([torch.zeros(5), torch.ones(5)], torch.tensor(0)), torch.zeros(5))
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[19], line 8, in test_stacklist()
#       6 @run_test
#       7 def test_stacklist():
# ----> 8     assert_eq(cf_stacklist([torch.zeros(5), torch.ones(5)], torch.tensor(0)), torch.zeros(5))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:231, in stack_op.<locals>.impl(self, inst)
#     229 @functools.wraps(fn)
#     230 def impl(self: "InstructionTranslatorBase", inst: Instruction):
# --> 231     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:711, in BuiltinVariable._make_handler.<locals>.<lambda>(tx, args, kwargs)
#     708 handlers = []
#     710 if any(issubclass(t, LazyVariableTracker) for t in arg_types):
# --> 711     return lambda tx, args, kwargs: obj.call_function(
#     712         tx, [v.realize() for v in args], kwargs
#     713     )
#     715 if obj.can_insert_in_graph() and not (
#     716     fn is operator.getitem
#     717     and not issubclass(arg_types[0], variables.TensorVariable)
#     718 ):
#     719     if obj.tensor_args_type(arg_types):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:830, in BuiltinVariable._make_handler.<locals>.builtin_dipatch(tx, args, kwargs)
#     828 def builtin_dipatch(tx, args, kwargs):
#     829     for fn in handlers:
# --> 830         rv = fn(tx, args, kwargs)
#     831         if rv:
#     832             return rv
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:750, in BuiltinVariable._make_handler.<locals>.call_self_handler(tx, args, kwargs)
#     748 def call_self_handler(tx, args, kwargs):
#     749     try:
# --> 750         result = self_handler(tx, *args, **kwargs)
#     751         if result is not None:
#     752             return result
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:1346, in BuiltinVariable.call_getitem(self, tx, *args, **kwargs)
#    1345 def call_getitem(self, tx, *args, **kwargs):
# -> 1346     return args[0].call_method(tx, "__getitem__", args[1:], kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/lists.py:307, in ListVariable.call_method(self, tx, name, args, kwargs)
#     305     return ConstantVariable.create(None)
#     306 else:
# --> 307     return super().call_method(tx, name, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/lists.py:267, in CommonListMethodsVariable.call_method(self, tx, name, args, kwargs)
#     265     return ConstantVariable.create(None)
#     266 else:
# --> 267     return super().call_method(tx, name, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/lists.py:127, in BaseListVariable.call_method(self, tx, name, args, kwargs)
#     125     else:
#     126         value = args[0]
# --> 127     return self.getitem_const(value)
#     128 elif name == "__contains__":
#     129     assert len(args) == 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/lists.py:103, in BaseListVariable.getitem_const(self, arg)
#     101 else:
#     102     assert isinstance(index, (int, torch.SymInt))
# --> 103     return self.items[index]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py:264, in SymInt.__index__(self)
#     263 def __index__(self):
# --> 264     return self.node.int_()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:349, in SymNode.int_(self)
#     348 def int_(self):
# --> 349     return self.guard_int("", 0)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:355, in SymNode.guard_int(self, file, line)
#     352 def guard_int(self, file, line):
#     353     # TODO: use the file/line for some useful diagnostic on why a
#     354     # guard occurred
# --> 355     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     356     try:
#     357         return int(r)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     237 try:
#     238     if args[0].is_recording:  # type: ignore[has-type]
#     239         # If ShapeEnv is already recording an event, call the wrapped
#     240         # function directly.
#     241         #
#     242         # NB: here, we skip the check of whether all ShapeEnv instances
#     243         # are equal, in favor of a faster dispatch.
# --> 244         return fn(*args, **kwargs)
#     246     # Retrieve an instance of ShapeEnv.
#     247     # Assumption: the collection of args and kwargs may not reference
#     248     # different ShapeEnv instances.
#     249     self = _extract_shape_env_and_assert_equal(args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4744         concrete_val = unsound_result
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#    4752     expr = new_expr
#
# GuardOnDataDependentSymNode: Could extract specialized integer from data-dependent expression u0 (unhinted: u0).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/lists.py", line 103, in getitem_const
#     return self.items[index]
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1545486673.py", line 4, in cf_stacklist
#     return xs[u0]
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# from user code:
#    File "/tmp/ipykernel_2254597/1545486673.py", line 4, in cf_stacklist
#     return xs[u0]
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# **[vb]** Some code in torchrec tests if all batches are the same size, and have an optimized codepath for this case.  If it's not statically known if this condition is true, it is better to force the unoptimized path unconditionally.  Modify the code so that it no longer compile errors.  In eager mode, you should still use the optimized codepath.  You may find the function `torch.compiler.is_dynamo_compiling()` helpful.

# %%
@torch.compile(fullgraph=True, backend="eager")
def cf_vb(xst: Tensor, y: Tensor):
    xs = xst.tolist()
    if all(xs[0] == x for x in xs):
        return (y.view(len(xs), -1) + torch.arange(len(xs)).unsqueeze(1)).view(-1)
    else:
        return torch.concat([t + i for i, t in enumerate(torch.split(y, xs, dim=0))], dim=0)

@run_test
def test_vb():
    assert_eq(cf_vb(torch.tensor([2, 2, 2]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 2, 2]))
    assert_eq(cf_vb(torch.tensor([2, 3, 1]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 1, 2]))
# Out:
# E0507 13:54:34.008752 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(Eq(u0, u1), None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1001, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1000 try:
# -> 1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:748, in guard_scalar(a)
#     747 if isinstance(a, (SymBool, bool)):
# --> 748     return guard_bool(a)
#     749 elif isinstance(a, (SymInt, int)):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:921, in guard_bool(a)
#     920 if isinstance(a, SymBool):
# --> 921     return a.node.guard_bool("", 0)  # NB: uses Python backtrace
#     922 assert type(a) is bool, a
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression Eq(u0, u1) (unhinted: Eq(u0, u1)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u1,u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/336448745.py", line 4, in cf_vb
#     if all(xs[0] == x for x in xs):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/polyfill.py", line 14, in all
#     if not elem:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[20], line 10
#       6     else:
#       7         return torch.concat([t + i for i, t in enumerate(torch.split(y, xs, dim=0))], dim=0)
#       9 @run_test
# ---> 10 def test_vb():
#      11     assert_eq(cf_vb(torch.tensor([2, 2, 2]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 2, 2]))
#      12     assert_eq(cf_vb(torch.tensor([2, 3, 1]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 1, 2]))
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[20], line 11, in test_vb()
#       9 @run_test
#      10 def test_vb():
# ---> 11     assert_eq(cf_vb(torch.tensor([2, 2, 2]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 2, 2]))
#      12     assert_eq(cf_vb(torch.tensor([2, 3, 1]), torch.zeros(6, dtype=torch.int64)), torch.tensor([0, 0, 1, 1, 1, 2]))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:1253, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1251 args = self.popn(inst.argval)
#    1252 fn = self.pop()
# -> 1253 self.call_function(fn, args, {})
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:737, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     735 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     736     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 737 self.push(fn.call_function(self, args, kwargs))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:830, in BuiltinVariable._make_handler.<locals>.builtin_dipatch(tx, args, kwargs)
#     828 def builtin_dipatch(tx, args, kwargs):
#     829     for fn in handlers:
# --> 830         rv = fn(tx, args, kwargs)
#     831         if rv:
#     832             return rv
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:750, in BuiltinVariable._make_handler.<locals>.call_self_handler(tx, args, kwargs)
#     748 def call_self_handler(tx, args, kwargs):
#     749     try:
# --> 750         result = self_handler(tx, *args, **kwargs)
#     751         if result is not None:
#     752             return result
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:92, in _polyfill_call_impl.<locals>.call_fn(self, tx, *args, **kwargs)
#      91 def call_fn(self, tx, *args, **kwargs):
# ---> 92     return tx.inline_user_function_return(
#      93         variables.UserFunctionVariable(fn), args, kwargs
#      94     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:743, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     739 def inline_user_function_return(self, fn, args, kwargs):
#     740     """
#     741     A call to some user defined function by inlining it.
#     742     """
# --> 743     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2448, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    2445 @classmethod
#    2446 def inline_call(cls, parent, func, args, kwargs):
#    2447     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2448         return cls.inline_call_(parent, func, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2564, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    2562 try:
#    2563     with strict_ctx:
# -> 2564         tracer.run()
#    2565 except exc.SkipFrame as e:
#    2566     msg = f"SKIPPED INLINING {code}: {e}"
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:448, in generic_jump.<locals>.inner(self, inst)
#     446 elif isinstance(value, SymNodeVariable):
#     447     try:
# --> 448         eval_result = value.evaluate_expr(self.output)
#     449     except exc.UserError as e:
#     450         if self.should_compile_partial_graph():
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py:1003, in SymNodeVariable.evaluate_expr(self, output_graph)
#    1001     return guard_scalar(self.sym_num)
#    1002 except GuardOnDataDependentSymNode as e:
# -> 1003     raise UserError(  # noqa: TRY200
#    1004         UserErrorType.ANTI_PATTERN,
#    1005         f"Consider annotating your code using torch._check*(). {str(e)}",
#    1006         case_name="constrain_as_size_example",
#    1007     )
#
# UserError: Consider annotating your code using torch._check*(). Could not guard on data-dependent expression Eq(u0, u1) (unhinted: Eq(u0, u1)).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/tensor.py", line 1001, in evaluate_expr
#     return guard_scalar(self.sym_num)
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u1,u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/336448745.py", line 4, in cf_vb
#     if all(xs[0] == x for x in xs):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/polyfill.py", line 14, in all
#     if not elem:
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/336448745.py", line 4, in cf_vb
#     if all(xs[0] == x for x in xs):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/polyfill.py", line 14, in all
#     if not elem:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# ## Jagged tensors: tensor splits
#
# **[tensorsplit]**  Your first idea will be to use `torch._check` to solve the errors. It will not work.  Instead, apply the idea from [changevar] to change the split computation from operating on unbacked SymInts representing offsets, to unbacked SymInts representing sizes.  You may find `torch.diff` and `torch.narrow` useful.

# %%
@torch.compile(fullgraph=True, backend="eager")
def cf_tensorsplit(x, offsets_t):
    offsets = offsets_t.tolist()
    rs = []
    for start, end in zip(offsets, offsets[1:]):
        rs.append(x[start:end])
    return rs

@run_test
def test_tensorsplit():
    assert_eq(
        cf_tensorsplit(torch.arange(10), torch.tensor([0, 2, 5, 7, 10])),
        [torch.tensor([0, 1]), torch.tensor([2, 3, 4]), torch.tensor([5, 6]), torch.tensor([7, 8, 9])]
    )
# Out:
# E0507 13:54:39.281540 140547765035008 torch/fx/experimental/recording.py:280] [0/0] failed while running evaluate_expr(*(u0 < 0, None), **{'fx_node': None})
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1557, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1556     with self:
# -> 1557         return decomposition_table[func](*args, **kwargs)
#    1559 with self:
#    1560     # Decomposes CompositeImplicitAutograd ops
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_decomp/decompositions.py:749, in slice_forward(self, dim, start, end, step)
#     747 end_val = end if end is not None else sys.maxsize  # 2^63 - 1
# --> 749 if start_val < 0:
#     750     start_val += sizes[dim]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py:378, in SymBool.__bool__(self)
#     377 def __bool__(self):
# --> 378     return self.node.bool_()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:439, in SymNode.bool_(self)
#     438 def bool_(self):
# --> 439     return self.guard_bool("", 0)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression u0 < 0 (unhinted: u0 < 0).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_decomp/decompositions.py", line 749, in slice_forward
#     if start_val < 0:
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1033318701.py", line 6, in cf_tensorsplit
#     rs.append(x[start:end])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1762, in get_fake_value(node, tx, allow_non_graph_fake)
#    1761     with tx.fake_mode, enable_python_dispatcher():
# -> 1762         ret_val = wrap_fake_exception(
#    1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1277, in wrap_fake_exception(fn)
#    1276 try:
# -> 1277     return fn()
#    1278 except UnsupportedFakeTensorException as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1763, in get_fake_value.<locals>.<lambda>()
#    1761     with tx.fake_mode, enable_python_dispatcher():
#    1762         ret_val = wrap_fake_exception(
# -> 1763             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1764         )
#    1765 except Unsupported:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1898, in run_node(tracer, node, args, kwargs, nnmodule)
#    1897     except Exception as e:
# -> 1898         raise RuntimeError(make_error_message(e)).with_traceback(
#    1899             e.__traceback__
#    1900         ) from e
#    1902 raise AssertionError(op)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1880, in run_node(tracer, node, args, kwargs, nnmodule)
#    1879 if op == "call_function":
# -> 1880     return node.target(*args, **kwargs)
#    1881 elif op == "call_method":
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/utils/_stats.py:20, in count.<locals>.wrapper(*args, **kwargs)
#      19 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20 return fn(*args, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:956, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#     955 try:
# --> 956     return self.dispatch(func, types, args, kwargs)
#     957 except TypeError:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1318, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1317 if self.cache_enabled:
# -> 1318     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1319 else:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1047, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1046 if output is _UNASSIGNED:
# -> 1047     output = self._dispatch_impl(func, types, args, kwargs)
#    1049 return output
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_subclasses/fake_tensor.py:1557, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1556     with self:
# -> 1557         return decomposition_table[func](*args, **kwargs)
#    1559 with self:
#    1560     # Decomposes CompositeImplicitAutograd ops
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_decomp/decompositions.py:749, in slice_forward(self, dim, start, end, step)
#     747 end_val = end if end is not None else sys.maxsize  # 2^63 - 1
# --> 749 if start_val < 0:
#     750     start_val += sizes[dim]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/__init__.py:378, in SymBool.__bool__(self)
#     377 def __bool__(self):
# --> 378     return self.node.bool_()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:439, in SymNode.bool_(self)
#     438 def bool_(self):
# --> 439     return self.guard_bool("", 0)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/sym_node.py:377, in SymNode.guard_bool(self, file, line)
#     374 def guard_bool(self, file, line):
#     375     # TODO: use the file/line for some useful diagnostic on why a
#     376     # guard occurred
# --> 377     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     378     try:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/recording.py:244, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     238 if args[0].is_recording:  # type: ignore[has-type]
#     239     # If ShapeEnv is already recording an event, call the wrapped
#     240     # function directly.
#     241     #
#     242     # NB: here, we skip the check of whether all ShapeEnv instances
#     243     # are equal, in favor of a faster dispatch.
# --> 244     return fn(*args, **kwargs)
#     246 # Retrieve an instance of ShapeEnv.
#     247 # Assumption: the collection of args and kwargs may not reference
#     248 # different ShapeEnv instances.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/fx/experimental/symbolic_shapes.py:4746, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4745     else:
# -> 4746         raise self._make_data_dependent_error(
#    4747             expr.xreplace(self.var_to_val),
#    4748             expr,
#    4749             size_oblivious_result=size_oblivious_result
#    4750         )
#    4751 else:
#
# RuntimeError: Failed running call_function <built-in function getitem>(*(FakeTensor(..., size=(10,), dtype=torch.int64), slice(u0, u1, None)), **{}):
# Could not guard on data-dependent expression u0 < 0 (unhinted: u0 < 0).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_decomp/decompositions.py", line 749, in slice_forward
#     if start_val < 0:
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1033318701.py", line 6, in cf_tensorsplit
#     rs.append(x[start:end])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# During handling of the above exception, another exception occurred:
#
# UserError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       6         rs.append(x[start:end])
#       7     return rs
#       9 @run_test
# ---> 10 def test_tensorsplit():
#      11     assert_eq(
#      12         cf_tensorsplit(torch.arange(10), torch.tensor([0, 2, 5, 7, 10])),
#      13         [torch.tensor([0, 1]), torch.tensor([2, 3, 4]), torch.tensor([5, 6]), torch.tensor([7, 8, 9])]
#      14     )
#
# Cell In[2], line 65, in run_test(fn)
#      63 def run_test(fn):
#      64     torch._dynamo.reset()
# ---> 65     fn()
#      66     print(MSG)
#
# Cell In[21], line 12, in test_tensorsplit()
#       9 @run_test
#      10 def test_tensorsplit():
#      11     assert_eq(
# ---> 12         cf_tensorsplit(torch.arange(10), torch.tensor([0, 2, 5, 7, 10])),
#      13         [torch.tensor([0, 1]), torch.tensor([2, 3, 4]), torch.tensor([5, 6]), torch.tensor([7, 8, 9])]
#      14     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/eval_frame.py:416, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     414 prior = set_eval_frame(callback)
#     415 try:
# --> 416     return fn(*args, **kwargs)
#     417 finally:
#     418     set_eval_frame(prior)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:981, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     977             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     979 with compile_lock, _disable_current_modes():
#     980     # skip=1: skip this frame
# --> 981     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:410, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     396 compile_id = CompileId(frame_id, frame_compile_id)
#     398 signpost_event(
#     399     "dynamo",
#     400     "_convert_frame_assert._compile",
#    (...)
#     407     },
#     408 )
# --> 410 return _compile(
#     411     frame.f_code,
#     412     frame.f_globals,
#     413     frame.f_locals,
#     414     frame.f_builtins,
#     415     compiler_fn,
#     416     one_graph,
#     417     export,
#     418     export_constraints,
#     419     hooks,
#     420     cache_size,
#     421     frame,
#     422     frame_state=frame_state,
#     423     compile_id=compile_id,
#     424     skip=skip + 1,
#     425 )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_utils_internal.py:301, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#     299 @functools.wraps(function)
#     300 def wrapper_function(*args, **kwargs):
# --> 301     return StrobelightCompileTimeProfiler.profile_compile_time(
#     302         function, phase_name, *args, **kwargs
#     303     )
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/caffe2/fb/strobelight/compile_time_profiler.py:102, in StrobelightCompileTimeProfiler.profile_compile_time(cls, func, phase_name, *args, **kwargs)
#      99 @classmethod
#     100 def profile_compile_time(cls, func, phase_name, *args, **kwargs):
#     101     if not cls.enabled:
# --> 102         return func(*args, **kwargs)
#     104     if cls.inside_profile_compile_time:
#     105         cls.ignored_profile_runs += 1
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/runtime/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:703, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     701 guarded_code = None
#     702 try:
# --> 703     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     704     return guarded_code
#     705 except (
#     706     Unsupported,
#     707     TorchRuntimeError,
#    (...)
#     714     BisectValidationException,
#     715 ) as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:273, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     271 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     272     t0 = time.time()
# --> 273     r = func(*args, **kwargs)
#     274     time_spent = time.time() - t0
#     275 compilation_time_metrics[key].append(time_spent)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:570, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     568 CompileContext.get().attempt = attempt
#     569 try:
# --> 570     out_code = transform_code_object(code, transform)
#     571     break
#     572 except exc.RestartAnalysis as e:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/bytecode_transformation.py:1167, in transform_code_object(code, transformations, safe)
#    1164 instructions = cleaned_instructions(code, safe)
#    1165 propagate_line_nums(instructions)
# -> 1167 transformations(instructions, code_options)
#    1168 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:172, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     170 cleanup = setup_compile_debug()
#     171 try:
# --> 172     return fn(*args, **kwargs)
#     173 finally:
#     174     cleanup.close()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/convert_frame.py:517, in _compile.<locals>.transform(instructions, code_options)
#     515 try:
#     516     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 517         tracer.run()
#     518 except exc.UnspecializeRestartAnalysis:
#     519     speculation_log.clear()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:2234, in InstructionTranslator.run(self)
#    2233 def run(self):
# -> 2234     super().run()
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:884, in InstructionTranslatorBase.run(self)
#     882 try:
#     883     self.output.push_tx(self)
# --> 884     while self.step():
#     885         pass
#     886 except BackendCompilerFailed:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:799, in InstructionTranslatorBase.step(self)
#     796 self.update_block_stack(inst)
#     798 try:
# --> 799     self.dispatch_table[inst.opcode](self, inst)
#     800     return not self.output.should_exit
#     801 except ReturnValueOp:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:494, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     492     return handle_graph_break(self, inst, speculation.reason)
#     493 try:
# --> 494     return inner_fn(self, inst)
#     495 except Unsupported as excp:
#     496     if self.generic_context_manager_depth > 0:
#     497         # We don't support graph break under GenericContextWrappingVariable,
#     498         # If there is, we roll back to the checkpoint and fall back.
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/symbolic_convert.py:231, in stack_op.<locals>.impl(self, inst)
#     229 @functools.wraps(fn)
#     230 def impl(self: "InstructionTranslatorBase", inst: Instruction):
# --> 231     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:711, in BuiltinVariable._make_handler.<locals>.<lambda>(tx, args, kwargs)
#     708 handlers = []
#     710 if any(issubclass(t, LazyVariableTracker) for t in arg_types):
# --> 711     return lambda tx, args, kwargs: obj.call_function(
#     712         tx, [v.realize() for v in args], kwargs
#     713     )
#     715 if obj.can_insert_in_graph() and not (
#     716     fn is operator.getitem
#     717     and not issubclass(arg_types[0], variables.TensorVariable)
#     718 ):
#     719     if obj.tensor_args_type(arg_types):
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:946, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     942 if not handler:
#     943     self.call_function_handler_cache[key] = handler = self._make_handler(
#     944         self.fn, [type(x) for x in args], bool(kwargs)
#     945     )
# --> 946 return handler(tx, args, kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builtin.py:925, in BuiltinVariable._handle_insert_op_in_graph(self, tx, args, kwargs)
#     921         if fn is operator.truediv and isinstance(
#     922             args[0], variables.UnspecializedPythonVariable
#     923         ):
#     924             args[0] = args[0].convert_to_constant(tx)
# --> 925         return wrap_fx_proxy(tx, proxy)
#     927 except NotImplementedError:
#     928     unimplemented(f"partial tensor op: {self} {args} {kwargs}")
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1519, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1511 kwargs = {
#    1512     "tx": tx,
#    1513     "proxy": proxy,
#    (...)
#    1516     **options,
#    1517 }
#    1518 if subclass_type is None:
# -> 1519     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1520 else:
#    1521     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/variables/builder.py:1604, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1600 # with preserve_rng_state():
#    1601 if example_value is None:
#    1602     # only allow_non_graph_fake in this instance because we handle the non-fake
#    1603     # cases properly below.
# -> 1604     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1606 # Handle recursive calls here
#    1607 elif maybe_get_fake_mode(example_value) is tx.fake_mode:
#
# File /mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_dynamo/utils.py:1817, in get_fake_value(node, tx, allow_non_graph_fake)
#    1809     unimplemented(
#    1810         f"unsupported operator: {cause.func} ({import_suggestion}see "
#    1811         "https://docs.google.com/document/d/1GgvOe7C8_NVOMLOCwDaYV1mXXyHMXY7ExoewHqooxrs/edit#heading=h.64r4npvq0w0"
#    1812         " for how to fix)"
#    1813     )
#    1814 elif isinstance(
#    1815     cause, torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode
#    1816 ):
# -> 1817     raise UserError(  # noqa: TRY200
#    1818         UserErrorType.CONSTRAINT_VIOLATION,
#    1819         "Tried to use data-dependent value in the subsequent computation. "
#    1820         "This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  "
#    1821         "You will need to explicitly give hint to the compiler. Please take a look at "
#    1822         f"torch._check OR torch._check_is_size APIs.  {cause}",
#    1823         case_name="constrain_as_size_example",
#    1824     )
#    1825 elif isinstance(cause, ValueRangeError):
#    1826     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
#
# UserError: Tried to use data-dependent value in the subsequent computation. This can happen when we encounter unbounded dynamic value that is unknown during tracing time.  You will need to explicitly give hint to the compiler. Please take a look at torch._check OR torch._check_is_size APIs.  Could not guard on data-dependent expression u0 < 0 (unhinted: u0 < 0).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/mnt/xarfuse/uid-128580/8438e84e-seed-nspid4026531836_cgpid58278121-ns-4026531840/torch/_decomp/decompositions.py", line 749, in slice_forward
#     if start_val < 0:
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# User Stack (most recent call last):
#   (snipped, see stack below for prefix)
#   File "/tmp/ipykernel_2254597/1033318701.py", line 6, in cf_tensorsplit
#     rs.append(x[start:end])
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#constrain-as-size-example
#
# from user code:
#    File "/tmp/ipykernel_2254597/1033318701.py", line 6, in cf_tensorsplit
#     rs.append(x[start:end])
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True
